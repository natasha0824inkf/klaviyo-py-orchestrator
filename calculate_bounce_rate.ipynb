# %%
# import relevant libraries

import pandas as pd

# %%
# load websites data

websites = pd.read_csv("websites.csv")

# %%
# display the first few rows

websites.head()
# Out:
#      website  visitors  bounces
# 0  website 1      1000      300
# 1  website 2       800      150
# 2  website 3      1200      200
# 3  website 4      1500      400
# 4  website 5       900      270

# %%
# get some basic information

websites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   website   50 non-null     object
#  1   visitors  50 non-null     int64
#  2   bounces   50 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.3+ KB

# %%
# calculate bounce rate as a percentage and add as a new column

websites["bounce_rate"] = (websites["bounces"] / websites["visitors"]) * 100

# %%
# view the updates

websites
# Out:
#        website  visitors  bounces  bounce_rate
# 0    website 1      1000      300    30.000000
# 1    website 2       800      150    18.750000
# 2    website 3      1200      200    16.666667
# 3    website 4      1500      400    26.666667
# 4    website 5       900      270    30.000000
# 5    website 6      1100       90     8.181818
# 6    website 7      1300      180    13.846154
# 7    website 8       950       80     8.421053
# 8    website 9      1150      130    11.304348
# 9   website 10      1050       70     6.666667
# 10  website 11      1400      200    14.285714
# 11  website 12       850       60     7.058824
# 12  website 13      1100      100     9.090909
# 13  website 14      1000       90     9.000000
# 14  website 15      1200      120    10.000000
# 15  website 16      1300      160    12.307692
# 16  website 17      1000       70     7.000000
# 17  website 18       800       40     5.000000
# 18  website 19      1200      110     9.166667
# ...
