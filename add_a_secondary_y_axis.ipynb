# %%
# import relevant libraries

import pandas as pd
import matplotlib.pyplot as plt

# %%
# load data from csv file into dataframe

data = pd.read_csv("analytics_search_data.csv")

# %%
# display the first few rows of the data

data.head()
# Out:
#      page  clicks  impressions  position                   avg_time  \
# 0  page 1     371       100673     42.59  0 days 00:01:43.666666666
# 1  page 2      80        30824     26.84  0 days 00:01:45.333333333
# 2  page 3      16         1458     30.64  0 days 00:04:06.000000000
# 3  page 4      11          517     36.05  0 days 00:00:22.333333333
# 4  page 5      10          140      5.61  0 days 00:02:52.000000000
#
#    bounce_rate  exit_rate  views  unique_views
# 0    47.296667  54.286667   1396          1095
# 1    64.436667  60.913333    210           181
# 2    53.335000  89.475000     30            26
# 3    58.170000  78.333333     27            21
# 4    22.223333  38.890000     15            13

# %%
# set the dataframe index to the "page" column and then remove the "page" column
# save the result in a new variable

data_updated = data.set_index("page", drop=True)

# %%
# check it out

data_updated.head()
# Out:
#         clicks  impressions  position                   avg_time  bounce_rate  \
# page
# page 1     371       100673     42.59  0 days 00:01:43.666666666    47.296667
# page 2      80        30824     26.84  0 days 00:01:45.333333333    64.436667
# page 3      16         1458     30.64  0 days 00:04:06.000000000    53.335000
# page 4      11          517     36.05  0 days 00:00:22.333333333    58.170000
# page 5      10          140      5.61  0 days 00:02:52.000000000    22.223333
#
#         exit_rate  views  unique_views
# page
# page 1  54.286667   1396          1095
# page 2  60.913333    210           181
# page 3  89.475000     30            26
# page 4  78.333333     27            21
# page 5  38.890000     15            13

# %%
# create subplots

fig, primary_axs = plt.subplots(1, 1, figsize=(15,5))

# add secondary axes

secondary_axs = primary_axs.twinx()

# create bar plot of clicks for first 10 pages

data_updated["clicks"][0:10].plot.bar(color="red", ax=primary_axs, position=1, width=0.2)

# create bar plot of views for first 10 pages

data_updated["views"][0:10].plot.bar(color="blue", ax=secondary_axs, position=0, width=0.2)

# add x-axis label 

primary_axs.set_xlabel("Page")

# add primary y-axis label

primary_axs.set_ylabel("Clicks")

# add secondary y-axis label

secondary_axs.set_ylabel("Views")

# add title

plt.title("Bar plot: Page Clicks vs. Page Views")

# show the plots

plt.show()
